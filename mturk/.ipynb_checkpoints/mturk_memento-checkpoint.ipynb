# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook will walk you through creating and monitoring your HITs.
#
# It provides methods to create HITs, pretty-print HIT and assignment status, expire/edit HITs, create qualifications, and download collected data.
#
# Before continuing, make sure that you have read the README and set all config fields to their desired values.
#
# ## Requirements:
#
# This code requires Python3 and the following packages:
# - boto3
# - beautiful soup 4
#
# Before using, you will have to set up an authentication key to use the Amazon API and include it in a credentials file. See here: https://aws.amazon.com/developers/getting-started/python/

# %% [markdown]
# # Setup

# %% [markdown]
# Read the config file and establish a connection to MTurk.
#
# A connection is made to production or to the sandbox based on values in the config.

# %%
import datetime
import boto3
import json
import copy
import pprint
from bs4 import BeautifulSoup as bs 
from uuid import uuid4
import csv
import os

# %%
# path to the config file 
CONFIG_PATH = "../config.json"

# where to save downloaded results 
SAVE_PATH = "assignments.json" 

# AWS profile to use
AWS_PROFILE_NAME = "memento"

# %%
USING_PROD = None
EXTERNAL_SUBMIT = None

# Read config and extract relevant settings
with open(CONFIG_PATH, 'r') as f:
    config = json.loads(f.read())
    
hit_config = config['hitCreation']

EXTERNAL_SUBMIT = config['advanced']['externalSubmit']

# Connection to production or sandbox 
if hit_config['production']:
    print("USING PROD")
    USING_PROD = True
    endpoint_url = 'https://mturk-requester.us-east-1.amazonaws.com'
    origin="production"
else:
    print("USING SANDBOX")
    USING_PROD = False
    endpoint_url = 'https://mturk-requester-sandbox.us-east-1.amazonaws.com'
    origin="sandbox"
    
hit_url = hit_config['taskUrl']
# If using an external link, add a querystring origin=sandbox or origin=production 
# for use in your js logic if you want. Not done for MTurk submits because it breaks the submit link
if (config['advanced']['externalSubmit']): 
    hit_url = "%s?origin=%s" % (hit_url, origin)
    
# Create an API connection
session = boto3.session.Session(profile_name=AWS_PROFILE_NAME)
cl = session.client('mturk', region_name='us-east-1', endpoint_url=endpoint_url)

print("Configuring task as external link with data submitted to: %s" % config['advanced']['externalSubmitUrl'] if EXTERNAL_SUBMIT else "Configuring task as an iframe within Mturk")
print("TASK URL: " + hit_url)
# Out:
# USING SANDBOX
# Configuring task as an iframe within Mturk
# TASK URL: https://memento-game.csail.mit.edu/

# %% [markdown]
# # Make new HIT

# %%
# Safety flags that prevent you from accidentally messing up your HITs. 
# Set to False except when you are performing these specific tasks. 
ALLOW_HIT_CREATION = True
ALLOW_ASSIGNMENT_ADDITION = False
ALLOW_CREATE_QUAL = False
ALLOW_UPDATE_EXPIRATION = False

# %%
# List of qualifications that you will use to filter potential workers. 
# These require that workers come from the US and have an approval rating >= 95%
# Edit this list to specify different qualifications for workers 
QUALS = [
       {
           'QualificationTypeId': '00000000000000000071',
           'Comparator': 'EqualTo',
           'LocaleValues': [{
               'Country': 'US',
           }],
       },
        
       {
           'QualificationTypeId': '000000000000000000L0',
           'Comparator': 'GreaterThanOrEqualTo',
           'IntegerValues': [
               95
           ],
       },
    ]

# %%
# Helpers for creating HITs. 

# generic helper that sets metadata fields based on the config file.
def create_hit(task, questionText): 
    response = cl.create_hit(
        MaxAssignments=task['numAssignments'],
        AutoApprovalDelayInSeconds=604800,
        LifetimeInSeconds=task['lifetime'],
        AssignmentDurationInSeconds=task['duration'],
        Reward=task['rewardAmount'],
        Title=task['title'],
        Keywords=task['keywords'],
        Description=task['description'],
        Question=questionText,
        QualificationRequirements=QUALS,
    )
    print(response)
    print("\n")

# creates a HIT in the form of an External Question inside an iFrame
def create_hit_iframe(task):
    questionText = "<ExternalQuestion xmlns=\"http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/"
    questionText += "2006-07-14/ExternalQuestion.xsd\">\n<ExternalURL>" + task['taskUrl']
    questionText += "</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>"
    create_hit(task, questionText)
    
# Helper to create a HIT in the form of a simple UI with a link to an external page and an
# input box for a completion code 
def create_hit_external(task):
    with open('questionform_template.xml', 'r') as myfile:
        template=myfile.read() 
    question_xml = template % (hit_config["title"], hit_config["description"], hit_url)
    create_hit(task, question_xml)

# %%
# Use this cell to launch your HIT! 
if ALLOW_HIT_CREATION: 
    if not (hit_config.get('variants', False) or hit_config.get('numTasks', False)): 
        raise RuntimeError("You must specify either hitCreation.numTasks or hitCreation.variants in your config.json file")
    
    hit_creation_function = create_hit_external if EXTERNAL_SUBMIT else create_hit_iframe
    
    if hit_config.get('numTasks', False): 
        print("creating " + str(hit_config['numTasks']) + " tasks")
        for i in range(hit_config['numTasks']):
            hit_creation_function(hit_config)
    else: 
        print("creating " + str(len(config['variants'])) + " variants")
        for var in hit_config['variants']: 
            task = copy.deepcopy(config)
            task.update(var)
            hit_creation_function(task)
else: 
    raise RuntimeError("This action is not currently enabled; set `ALLOW_HIT_CREATION` to true to proceed with this action")
# Out:
# creating 100 tasks
# {'HIT': {'HITId': '3ACRLU860PT884G3LRL6QZNWRBSBE4', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 25, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 45, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '6494890c-a42f-40fb-8911-71b75e271036', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '6494890c-a42f-40fb-8911-71b75e271036', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:24 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '39HYCOOPKQ0ZZP60GL0VYXG53YVDM2', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 25, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 45, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '26f0d3f8-7f1d-4259-969d-8d80196878af', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '26f0d3f8-7f1d-4259-969d-8d80196878af', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:24 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3M0556243UZ2FR5WJSALZC8QK1LFNF', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 25, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 45, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'f43b0072-3b47-4216-b437-b76f12092cbd', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'f43b0072-3b47-4216-b437-b76f12092cbd', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:25 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3IH9TRB0FDEJBB0XFDI8528FXS8I11', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 25, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 45, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '50814fe6-8a8e-45ab-9d17-91ec936238df', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '50814fe6-8a8e-45ab-9d17-91ec936238df', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:25 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3BS6ERDL95MXAML8T5TE91JJDYG6DL', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 25, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 45, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'cb8fda32-956a-4b15-bbff-572d5b468188', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'cb8fda32-956a-4b15-bbff-572d5b468188', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:25 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3Z8UJEJOC1SMADL9YNQEG2O9CMZ931', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 25, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 45, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '9992dfe5-9e03-4900-9c9b-1da2228469f0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '9992dfe5-9e03-4900-9c9b-1da2228469f0', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:25 GMT'}, 'RetryAttempts': 0}}
# {'HIT': {'HITId': '3S8APUMBJZY0EIGZG25C8H8W3C7BFM', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 26, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 46, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'bc78a8a2-1f44-45f8-a0ee-eef8261add56', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'bc78a8a2-1f44-45f8-a0ee-eef8261add56', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:25 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3O0M2G5VC8H7S94DY1VXQ7GFQMV94M', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 28, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 48, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'fa895f17-0855-40e0-8a8e-10fec6c59693', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'fa895f17-0855-40e0-8a8e-10fec6c59693', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:27 GMT'}, 'RetryAttempts': 2}}
#
#
# {'HIT': {'HITId': '3OREP8RUT4Q6SICURMBUQ2884R7BGL', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 28, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 48, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '28ed822e-d7f7-4764-9f8b-28a679bb05ef', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '28ed822e-d7f7-4764-9f8b-28a679bb05ef', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:28 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '341YLJU21KEQ0WITYHIMALIKPYMI2I', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 28, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 48, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '1b074520-0471-44c2-9349-93d908300f26', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '1b074520-0471-44c2-9349-93d908300f26', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:28 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3WA2XVDZEOW22SZ8P04YFJ14DAH6EE', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 28, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 48, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'dd7cfb8f-97a8-4d70-973e-b95b93cd2700', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'dd7cfb8f-97a8-4d70-973e-b95b93cd2700', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:28 GMT'}, 'RetryAttempts': 0}}
# {'HIT': {'HITId': '3E6L1VR4XY1U86Z4KBO4X1M4PBW6FW', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 29, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 49, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'ad61a089-0608-4970-80c6-3671bd9f0513', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'ad61a089-0608-4970-80c6-3671bd9f0513', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:29 GMT'}, 'RetryAttempts': 2}}
#
#
# {'HIT': {'HITId': '3JMQI2OLF1K5H7R0SMFVBC558O5DN2', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 29, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 49, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'e76577d7-b791-4192-94c1-2ffe77a98ff7', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'e76577d7-b791-4192-94c1-2ffe77a98ff7', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:29 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3OQQD2WO8KLFLEEC2HWRTVNCVCMI3T', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 30, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 50, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '534ac786-8c27-4dcd-a15d-96e3119cb1b8', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '534ac786-8c27-4dcd-a15d-96e3119cb1b8', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1258', 'date': 'Thu, 28 Feb 2019 18:56:30 GMT'}, 'RetryAttempts': 1}}
#
#
# {'HIT': {'HITId': '37VE3DA4YWWKSE75BSTCB2K9JRKBHK', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 30, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 50, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'adc0cfcb-cbc2-4b8b-aa78-29408e76b003', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'adc0cfcb-cbc2-4b8b-aa78-29408e76b003', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1258', 'date': 'Thu, 28 Feb 2019 18:56:30 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3RSBJ6YZEE5KXC58K7AYE18VABQFOU', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 30, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 50, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'defca0da-89d0-4150-ba1d-b70f4ff12bc7', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'defca0da-89d0-4150-ba1d-b70f4ff12bc7', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1258', 'date': 'Thu, 28 Feb 2019 18:56:30 GMT'}, 'RetryAttempts': 0}}
# {'HIT': {'HITId': '3APP19WN73T0M6VZVVUMFMMGQQW6GV', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 31, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 51, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'c011b254-46e9-4661-a11b-3853368a4fdf', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'c011b254-46e9-4661-a11b-3853368a4fdf', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:31 GMT'}, 'RetryAttempts': 1}}
#
#
# {'HIT': {'HITId': '3JYPJ2TAYKN2ICH9Z7ND31DLKGMFPB', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 31, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 51, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '74d1aac9-4f44-4f11-af00-0e6bb5972897', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '74d1aac9-4f44-4f11-af00-0e6bb5972897', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:31 GMT'}, 'RetryAttempts': 1}}
#
#
# {'HIT': {'HITId': '3DIIW4IV8RA03AXG2V1A30FI9CII4E', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 32, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 52, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'b4ff3e21-85ce-4947-b83d-603be29e6d81', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'b4ff3e21-85ce-4947-b83d-603be29e6d81', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:32 GMT'}, 'RetryAttempts': 1}}
#
#
# {'HIT': {'HITId': '3BVS8WK9Q2AKO9IPHABXBELOJ4ZBID', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 32, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 52, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'c392f925-50c7-4a2e-8856-770f3cf77fc6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'c392f925-50c7-4a2e-8856-770f3cf77fc6', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:32 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '35A1YQPVFGVIZT1GG0KK8SLW98DI5J', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 33, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 53, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '633e17d0-5cf9-4832-890a-5a696651e46e', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '633e17d0-5cf9-4832-890a-5a696651e46e', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:33 GMT'}, 'RetryAttempts': 1}}
#
#
# {'HIT': {'HITId': '3TTPFEFXCVZEM2QAF1C40MYH5Q96HU', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 33, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 53, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '007c9bde-164f-4a4b-b1f6-49d156dc90c7', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '007c9bde-164f-4a4b-b1f6-49d156dc90c7', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:33 GMT'}, 'RetryAttempts': 0}}
# {'HIT': {'HITId': '3PCPFX4U425NIOIOZK22363VPC8FQ2', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 35, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 55, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'a3a1f753-0baf-4334-8d06-c2d6f5516025', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'a3a1f753-0baf-4334-8d06-c2d6f5516025', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:35 GMT'}, 'RetryAttempts': 2}}
#
#
# {'HIT': {'HITId': '3B9XR6P1WGAGJK2VZSWXNF0OWJOBJP', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 36, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 56, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '5d98e8bb-c217-4d21-9770-721c66858f24', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '5d98e8bb-c217-4d21-9770-721c66858f24', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:35 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3XT3KXP241DEIX1ULJUP0YZW53OI6Z', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 36, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 56, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '1d4c06b5-4fcd-4abe-a532-f40f0fbadd90', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '1d4c06b5-4fcd-4abe-a532-f40f0fbadd90', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:35 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3XT3KXP241DEIX1ULJUP0YZW53O6IN', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 36, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 56, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '6fa46714-002a-49b9-921a-60b439e14e06', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '6fa46714-002a-49b9-921a-60b439e14e06', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:35 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3OEWW2KGQLQNZSRCT1F8Q15AYYADOH', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 56, 37, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 29, 57, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'aaa6eb66-bbec-4f43-91ff-ea84aecdedf0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'aaa6eb66-bbec-4f43-91ff-ea84aecdedf0', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:56:37 GMT'}, 'RetryAttempts': 1}}
#
#
# ...
#
#
# {'HIT': {'HITId': '36AZSFEYZ6FPAF2PGHAGQ3BIR6VBVA', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 57, 9, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 30, 29, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'b6780abf-3f41-4ac0-92b0-29ab8db7ccce', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'b6780abf-3f41-4ac0-92b0-29ab8db7ccce', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:57:08 GMT'}, 'RetryAttempts': 1}}
#
#
# {'HIT': {'HITId': '3T6SSHJUZHPUBHWVNK3EX1P1EUJIIT', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 57, 10, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 30, 30, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '3b1e0dab-97de-42aa-bd97-2daa77403452', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '3b1e0dab-97de-42aa-bd97-2daa77403452', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1258', 'date': 'Thu, 28 Feb 2019 18:57:10 GMT'}, 'RetryAttempts': 1}}
#
#
# {'HIT': {'HITId': '3W9XHF7WGMABQQ2UHZNUOO6NHFOKTN', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 57, 10, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 30, 30, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '95ee5d4b-db48-4827-a4fa-f2bd78106af2', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '95ee5d4b-db48-4827-a4fa-f2bd78106af2', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1258', 'date': 'Thu, 28 Feb 2019 18:57:10 GMT'}, 'RetryAttempts': 0}}
# {'HIT': {'HITId': '3JMQI2OLF1K5H7R0SMFVBC558O5NDC', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 57, 10, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 30, 30, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'abff251e-a032-4aea-b98a-7f951cddaac4', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'abff251e-a032-4aea-b98a-7f951cddaac4', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1258', 'date': 'Thu, 28 Feb 2019 18:57:10 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3WRBLBQ2GTN58V9KT6E56LCPDNAG04', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 57, 10, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 30, 30, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'ea08bc21-6178-412f-bdb2-0a014f0535ab', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'ea08bc21-6178-412f-bdb2-0a014f0535ab', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1258', 'date': 'Thu, 28 Feb 2019 18:57:10 GMT'}, 'RetryAttempts': 1}}
#
#
# {'HIT': {'HITId': '344M16OZKKUA9D50OHQFHUNQ806NE5', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 57, 10, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 30, 30, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '1760fa03-0f31-4ea2-9304-5beba9d92bfc', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '1760fa03-0f31-4ea2-9304-5beba9d92bfc', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1258', 'date': 'Thu, 28 Feb 2019 18:57:10 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3RKHNXPHGYBQQ3HJH4D4TKSP0TVKUE', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 57, 13, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 30, 33, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'f7018c74-ea8d-4b3b-bcf2-2f92a8110574', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'f7018c74-ea8d-4b3b-bcf2-2f92a8110574', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:57:12 GMT'}, 'RetryAttempts': 2}}
#
#
# {'HIT': {'HITId': '3TKXBROM5VPQ6SG152OE9241R98IJ5', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 57, 13, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 30, 33, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'b3dee430-9f1e-4884-b37e-c478c2517ff4', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'b3dee430-9f1e-4884-b37e-c478c2517ff4', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:57:12 GMT'}, 'RetryAttempts': 0}}
#
#
# {'HIT': {'HITId': '3VDVA3ILIFU5FKU2PPI5KQVZIFGG17', 'HITTypeId': '34Z8PDG356YP9F7DE9ZA7TGV8DRE5H', 'HITGroupId': '38KT5K3J4M24SQ2W0F3YSNH9MWIQJD', 'CreationTime': datetime.datetime(2019, 2, 28, 13, 57, 13, tzinfo=tzlocal()), 'Title': 'Memento: The Video Memory Game', 'Description': 'Indicate which videos you remember by playing a simple memory game on short 3 second videos!', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://memento-game.csail.mit.edu/</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'videos, memorability, memory, game, fun', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 1, 19, 30, 33, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1200, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'f48b6524-cb0c-4b10-b821-9add00ac8a5c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'f48b6524-cb0c-4b10-b821-9add00ac8a5c', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1260', 'date': 'Thu, 28 Feb 2019 18:57:12 GMT'}, 'RetryAttempts': 0}}

# %% [markdown]
# # HIT monitoring helpers

# %% [markdown]
# Helper functions that will be useful for monitoring the status of your HIT. See next section for how to use them.

# %%
# Contacts MTurk API to get all assignments for a HIT
# Returns them in a list. 
def get_all_assignments(hitid): 
    assignments = []
    should_continue = True
    next_token = False
    while (should_continue): 
        args = {
            'HITId': hitid, 
            'MaxResults': 100
        }
        if (next_token): 
            args['NextToken'] = next_token
        r = cl.list_assignments_for_hit(**args)
        next_token = r.get('NextToken', False)
        assignments.extend(r["Assignments"])
        should_continue = len(r["Assignments"]) > 0
    return assignments

# Summarizes all hits in `hits` in a human-readable way. 
# Prints out the HIT Title, id, if it is expired, and how many assignments it has
# completed, pending, and left for work. 
def summarize_hits(hits): 
    print(len(hits))
    ret = ""
    for hit in hits: 
        expiration = hit['Expiration'].replace(tzinfo=None)
        is_expired = expiration < datetime.datetime.now()
        description = ("Title: {title}\n" 
        "ID: {hid}\n"
        "\tAssignments left: {left}\n"
        "\tAssignments completed: {complete}\n"
        "\tAssignments pending: {pending}\n"
        "\tExpired: {exp}\n\n").format(
            title=hit['Title'], 
            hid=hit['HITId'], 
            left=hit['NumberOfAssignmentsAvailable'], 
            complete=hit['NumberOfAssignmentsCompleted'], 
            pending=hit['NumberOfAssignmentsPending'],
            exp=str(is_expired)
        )
        ret += description
    print(ret)
    
# Prints a human-readable summary of all pending/submitted/approved assignments for all hits in `hits`
def summarize_assignments(hits):
    ret = ""
    for hit in hits: 
        hid = hit['HITId']
        title =  hit['Title']
        name = "HIT %s: %s" % (hid, title)
        ret += name + "\n"
        assignments = get_all_assignments(hid)
        if len(assignments) == 0: 
            ret += "\tNo pending/submitted/approved assignments for this HIT\n"
        for a in assignments: 
            desc = "\tAssignment {aid}\n\t\tStatus: {status}\n".format(aid=a['AssignmentId'], status=a['AssignmentStatus'])
            ret += desc
    print(ret)
    
# Refreshes data about the requested hits
def refresh_hits(): 
    global hits 
    global MAX_RESULTS
    hits = cl.list_hits(MaxResults=MAX_RESULTS)['HITs']

# %% [markdown]
# # HIT monitoring

# %%
MAX_RESULTS = 100 # set equal to the number of outstanding hits you have 

# API call to grab HIT data from MTurk 
hits = cl.list_hits(MaxResults=MAX_RESULTS)['HITs']

# %%
# Summarizes all outstanding HITs
refresh_hits()
summarize_hits(hits)
# Out:
# 100
# Title: Memento: The Video Memory Game
# ID: 3DQYSJDTYNQFL7J4QNFIKMOHIE0XEY
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3HEADTGN2R7CQMJECEY0V8QFHSIRV2
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3W3RSPVVGU61A9Z124RZDAFXXTKULQ
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3EFNPKWBMU34EJXWYR9FSHX9HJQ03I
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 37PGLWGSJVLLHCMJNNQKF7E7EYSIK3
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3C8QQOM6JRGW1I418N2LU7RM3YXIL6
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3S829FDFT4GAT154US4YE46WI2ZXD5
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3DFYDSXB2YFVFJB1ZJFMXV25T4FUJO
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 362E9TQF2J5GFQQ0XW55HFME7HBIG0
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3ZICQFRS33X21XAFNSHG2H5AEK7ZZ3
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3D1TUISJWKFZK8RVH1UMLUN5GPQUIC
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3RWB1RTQDL2T3X7MRTJ1YZ6S5CTP83
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3FSEU3P2NTFKXF2X3UTQUB1CWM5RR9
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 391FPZIE4E1ZODGBBJC1LIMQGCBUHJ
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3HXCEECSQO82W70AR6FXOAW88Q3ZYC
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 307L9TDWJ077ZFP3ZXBD3TTMPB0N3D
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3P7RGTLO6GS6BU3LBZY7Y9QO1QNKA1
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3GITHABAC00IEXTKVXX8KJOUJX0N22
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 31SIZS5W5BUKLENXQF4QPLR7003RQ8
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3P7RGTLO6GS6BU3LBZY7Y9QO1QNAKR
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3VEI3XUCZTCZL2MIQ2P1PG1XV4HRPH
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 31YWE12TE2RUCS4U3F1CECW0WRWX7C
# 	Assignments left: 0
# 	Assignments completed: 0
#
# Title: Memento: The Video Memory Game
# ID: 3QD8LUVX4ZDFPOQBFMMFGSI45L1X5X
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3EPG8DX9LM5AGFOKTVCYMFW13MSP51
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3IWA71V4TKVB8SQPK5WK8YW41GCX6D
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3W0KKJIARTOSS6A6E1ET2IKTB2NK8X
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3IKDQS3DQGF3YEAVVA9MRO1Z9PJICQ
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3CIS7GGG67YN43P9LI4V0FPDOWJUE3
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3TX9T2ZCBBGY725AC5X93DBSXI3ZWD
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3BCRDCM0OF95OSRILMHVI4O257XK6B
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3YGYP13643OZIHA5ANC9LRW2VPGRNL
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3MXX6RQ9EXKSKWKKFQTOHNQN3QXP4W
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3UEDKCTP9X5OSS5N4WMNOIOY0IHK7A
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 37OPIVELUWIF942D5EVALHAW99JAHN
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 39RRBHZ0AWGLSD55MVSDHBSEQ91ZV3
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3JTPR5MTZUR95OR4G37QQYA29CMK5V
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3Y3N5A7N4IO2X01RCHP3G80ZTMLMYI
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# HIT 3Y7LTZE0YV1LFYG5H5I8LPQVC2SZUE: Memento: The Video Memory Game
# 	Assignment 379J5II41RVM8X0926HVXCOILFNLE6
# 		Status: Submitted
# HIT 34OWYT6U3YW10G3SJQZVPY0R34GI99: Memento: The Video Memory Game
# 	Assignment 3A4NIXBJ79EKKLSMJ45EAKTRUHGMLY
# 		Status: Submitted
# HIT 329E6HTMSYH6R9402KJXB1CIVGVK35: Memento: The Video Memory Game
# 	Assignment 3MX2NQ3YCC9HC8O55ORG4CDSFVY5XB
# 		Status: Submitted
# HIT 3VQTAXTYN50PX0DPBR25Z7JSLZ6UB3: Memento: The Video Memory Game
# 	Assignment 37QW5D2ZRJ1S39L89CSWHO6R26X8S8
# 		Status: Submitted
# HIT 33W1NHWFYJ06FL1GH0SYGT4TTOLZTN: Memento: The Video Memory Game
# 	Assignment 3RWE2M8QWKPD57O06CYVPFQ3WAHN0U
# 		Status: Submitted
# HIT 3A3KKYU7P5WY8V6RXG7FVBFJIELMWJ: Memento: The Video Memory Game
# 	Assignment 3Y5140Z9D0VOFNHTQH0TZ8VUIIVIPA
# 		Status: Submitted

# %% [markdown]
# # Approve HITs

# %% [markdown]
# Approves all outstanding assignments for the HITs displayed above.

# %%
def approve_all(hits): 
    num_approved = 0
    for hit in hits: 
        # make sure you keep getting assignments 
        assignments = get_all_assignments(hit["HITId"])
#         print(assignments)
        for a in assignments: 
            if a['AssignmentStatus'] != 'Approved':
                print("Approving assignment")
                num_approved += 1
                cl.approve_assignment(AssignmentId=a['AssignmentId'])
    print("Approved %d assignments" % num_approved)

# def approve_all(assignments): 
#     for a in assignments: 
        
#         print(a)
#         cl.approve_assignment(AssignmentId=a['AssignmentId'])
#     print("Succesfully approved %d assignments" % len(assignments))

# %%
# refresh_hits()
approve_all(hits)
# Out:
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approved 100 assignments

# %% [markdown]
# # Update expiration or num tasks

# %%
# changes the expiration date on a HIT to days_from_now days in the future
def update_expiration(hitid, days_from_now): 
    if ALLOW_UPDATE_EXPIRATION: 
        days = days_from_now*datetime.timedelta(days=1)
        expire_time = datetime.datetime.now() + days

        response = cl.update_expiration_for_hit(HITId=hitid, ExpireAt=expire_time)
        print(response)
        return response
    else: 
        raise RuntimeError("This action is not currently enabled; set `ALLOW_UPDATE_EXPIRATION` to true to proceed with this action")
    
def expire_hit(hit): 
    return update_expiration(hit, -10)

# %%
def add_assignments(hitid, num_assignments): 
    if ALLOW_ASSIGNMENT_ADDITION: 
        response = cl.create_additional_assignments_for_hit(
            HITId=hitid,
            NumberOfAdditionalAssignments=num_assignments
        )
        print(response)
        return response
    else: 
        raise RuntimeError("This action is not currently enabled; set `ALLOW_ASSIGNMENT_ADDITION` to true to proceed with this action")

# %%
# Use this cell to expire a HIT 
HIT_id_to_expire = "FILL THIS IN" 
expire_hit(HIT_id_to_expire)

# %%
# Use this cell to add assignments to a HIT 
HIT_id_to_add_assignments = "FILL THIS IN"
num_assignments_to_add = 0
add_assignments(HIT_id_to_add_assignments, num_assignments_to_add)

# %% [markdown]
# # Add custom qualifications

# %% [markdown]
# ## Add a qualification to disqualify workers who have done work before
#
# - uses "negative qualification" method from https://github.com/cloudyr/MturkR/wiki/qualifications-as-blocks
#
# #### NOTE: quals are kept separate for the sandbox and prod. Make sure you are creating and assigning your quals in prod.

# %% [markdown]
# ### Structure of a new qualification

# %%
NEW_QUAL = {
    'Name': 'qualName',
    'Keywords': 'Keywords for qual',
    'Description': 'What is this qual, and why are you assigning it?',
    'QualificationTypeStatus': 'Active',
    'AutoGranted': False
}

# %% [markdown]
# ### Helpers for creating, viewing, and assigning qualifications

# %%
# Registers a custom qualification with MTurk 
def create_qual(new_qual):
    if ALLOW_CREATE_QUAL: 
        response = cl.create_qualification_type(**new_qual)
        print(response)
        Id = response['QualificationTypeId']
        print("id", Id)
        return Id
    else: 
        raise RuntimException("This action is not currently enabled; set `ALLOW_CREATE_QUAL` to true to proceed with this action")
        
# Gets all the custom quals you have created and prints them
def list_quals(): 
    response = cl.list_qualification_types(
            Query='hasCompletedVisualGraphRecallTask',
            MustBeRequestable=False
    )
    print(response)
    
# Assigns a qualification to a worker 
def assign_qual(qual_id, worker_ids): 
    for worker in worker_ids: 
        response = cl.associate_qualification_with_worker(
                QualificationTypeId=qual_id, 
                WorkerId=worker,
                IntegerValue=1,
                SendNotification=False
        )
        print(response)
        assert response
        
# Gets the ids of all workers who worked on a particular hit 
def get_workers_for_hit(hitid): 
    a = get_all_assignments(hitid)
    workers = [a_['WorkerId'] for a_ in a]
    return workers
    
# Confirms that every worker in worker_ids has qual with qual_id
def confirm_quals(qual_id, worker_ids): 
    for w in worker_ids: 
        response = cl.get_qualification_score(
                QualificationTypeId=qual_id,
                WorkerId=w
        )
        response = response['Qualification']
        assert response['Status'] == 'Granted'
        assert response['IntegerValue'] == 1
        
# Assigns qual with `qual_id` to every worker who has completed an assignment for the hit with `hitid`
def assign_qual_for_hit(hitid, qual_id): 
    workers = get_workers_for_hit(hitid)
    print("got workers")
    assign_qual(qual_id, workers)
    print("assigned qual")
    confirm_quals(qual_id, workers)
    print("confirmed qual")

# %% [markdown]
# ### Use the following cells to manipulate qualifications

# %%
# Use this cell to view the custom qualifications you have created
list_quals()

# %%
# Use this cell to create a new qual 
qual_to_create = {}
create_qual(qual_to_create)

# %%
# Use this cell to assign a custom qual to every worker who has done a specific HIT
hit_id = "FILL THIS IN"
qual_id_to_assign = "FILL THIS IN"
assign_qual_for_hit(hit_id, qual_id_to_assign)

# %% [markdown]
# # Create Compensation HIT
#
# Mistakes happen, and sometimes they can lead to a worker who put in an honest effort being unable to complete a task and get paid. It's a good idea to compensate these workers when they reach out because it helps maintain relations with workers and is the right thing to do.
#
# However, workers can only be paid upon completing a task. The workaround is to create a custom qualification, assign it to the worker you want to compensate, and create a no-work HIT requiring the custom qualification. This code does that.

# %%
# worker_ids is str[]
# compensation is str but should match the regex ^\d*\.\d\d$ (e.g. "1.00")
# for_hit_id is str -- optional, but helpful for records
def compensate_workers(worker_ids, compensation, for_hit_id=""):
    with open('compensation.xml', 'r') as myfile:
        question_xml=myfile.read()

    keywords = 'compensation'
    description = 'Compensation for HIT'
    if for_hit_id:
        keywords += ', ' + for_hit_id
        description += ' ' + for_hit_id

    # create qual, assign to workers
    custom_qual = {
        'Name': str(uuid4()), # a qual must have a unique name
        'Keywords': keywords,
        'Description': description,
        'QualificationTypeStatus': 'Active',
        'AutoGranted': False
    }
    qual_id = create_qual(custom_qual)
    assign_qual(qual_id, worker_ids)

    # create HIT requiring qual
    task = {
        'numAssignments': len(worker_ids),
        'lifetime': 3 * 24 * 60 * 60, # 3 days
        'duration': 5 * 60, # 5 min
        'rewardAmount': compensation,
        'title': description,
        'keywords': keywords,
        'description': description,
    }
    quals = [{
        'QualificationTypeId': qual_id,
        'Comparator': 'Exists',
        'ActionsGuarded': 'DiscoverPreviewAndAccept'
    }]
    create_hit(task, question_xml, quals)

# %%
worker_ids = ['A35H05K4OCYQ0S'] # worker_id strings in a list
compensation = "1.50" # change to the amount of dollars you want to give
for_hit_id = "3CL9ACF21N3XOSJBS5A8GX3DPU6W65" # hit_id string (what you are compensating for)
compensate_workers(worker_ids, compensation, for_hit_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d04d4ab3a756> in <module>
#       2 compensation = "1.50" # change to the amount of dollars you want to give
#       3 for_hit_id = "3CL9ACF21N3XOSJBS5A8GX3DPU6W65" # hit_id string (what you are compensating for)
# ----> 4 compensate_workers(worker_ids, compensation, for_hit_id)
#
# <ipython-input-20-619c43d748de> in compensate_workers(worker_ids, compensation, for_hit_id)
#      14     # create qual, assign to workers
#      15     custom_qual = {
# ---> 16         'Name': str(uuid4()), # a qual must have a unique name
#      17         'Keywords': keywords,
#      18         'Description': description,
#
# NameError: name 'uuid4' is not defined

# %% [markdown]
# # Download data

# %% [markdown]
# Helper to download data from MTurk

# %%
from bs4 import BeautifulSoup as bs 
import pprint

def pretty_print(obj):
    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(obj)
    pp = None
    
def get_data_from_assignment(a): 
    a_xml = a['Answer']
    soup = bs(a_xml, "html.parser")
    answers = soup.find_all("answer")
    results = {'HITId': a['HITId'], 'AssignmentId': a['AssignmentId'], 'WorkerId': a['WorkerId']}
    for ans in answers: 
        identifier = ans.find('questionidentifier').string
        answer = ans.find('freetext').string
        try: 
            results[identifier] = json.loads(answer)
        except:
            results[identifier] = answer
    return results

# Downloads all the assignments completed for `hits` as a list of dictionaries. 
# If a download_path is given, also saves that data as json 
def get_assignment_content(hits, download_path="", should_print=False): 
    all_responses = []
    for hit in hits: 
        hitid = hit['HITId']
        assignments = get_all_assignments(hitid)
        for a in assignments:
            results = get_data_from_assignment(a)
            all_responses.append(results)
    if should_print: 
        pretty_print(all_responses)
    if download_path: 
        with open(download_path, 'w') as outfile: 
            json.dump(all_responses, outfile)
    return all_responses

_string_clean = lambda s: s.strip().lower()

def test_assignments_for_approval(hits, condition=lambda x: True): 
    to_approve = []
    to_reject = [] 
    for hit in hits: 
        # make sure you keep getting assignments 
        assignments = get_all_assignments(hit["HITId"])
        #print(assignments)
        for a_raw in assignments: 
            a = get_data_from_assignment(a_raw)
            if a_raw['AssignmentStatus'] != 'Approved':
                print("Testing assignment")
                data = condition(a)
                if (data): 
                    print("\tApproved")
                    to_approve.append(a)
                else: 
                    print("\tRejected")
                    to_reject.append(a)
    print("Found %d assignments to approve" % len(to_approve))
    print("Found %d assignments to reject" % len(to_reject))
    return to_approve, to_reject

def approve_all(assignments): 
    for a in assignments: 
        cl.approve_assignment(AssignmentId=a['AssignmentId'])
    print("Succesfully approved %d assignments" % len(assignments))

def get_levels_table(): 
    # WARNING: this assumes you have dumped the most recent version of the db into the folder dump/
    rows = []
    with open(os.path.join("..", "dump", "levels.tsv")) as tsvfile:
        reader = csv.reader(tsvfile, delimiter='\t')
        is_header = True
        headers = {}
        for row in reader:
            if is_header: 
                for i, elt in enumerate(row): 
                    headers[i] = elt
                is_header = False
            else: 
                data = dict([(val, row[key]) for key, val in headers.items()])
                rows.append(data)
    return rows

def is_valid_assignment(a, levels): 
    possible_levels = [l for l in levels if l['assignment_id'] == a['AssignmentId'] and l['score'] is not 'NULL']
    if not possible_levels: 
        return False
    return True

    
    #try: 
    return True
#     except Exception as e: 
#         print("error", e)
#         return False

# %%
# Use this cell to download data
responses = get_assignment_content(hits, download_path=SAVE_PATH, should_print=True)
pass

# %%
levels = get_levels_table()
condition = lambda a: is_valid_assignment(a, levels)
to_approve, to_reject = test_assignments_for_approval(hits, condition=condition)

# %%
approve_all(to_approve)
