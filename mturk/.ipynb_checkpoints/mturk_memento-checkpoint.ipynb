# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook will walk you through creating and monitoring your HITs.
#
# It provides methods to create HITs, pretty-print HIT and assignment status, expire/edit HITs, create qualifications, and download collected data.
#
# Before continuing, make sure that you have read the README and set all config fields to their desired values.
#
# ## Requirements:
#
# This code requires Python3 and the following packages:
# - boto3
# - beautiful soup 4
#
# Before using, you will have to set up an authentication key to use the Amazon API and include it in a credentials file. See here: https://aws.amazon.com/developers/getting-started/python/

# %% [markdown]
# # Setup

# %% [markdown]
# Read the config file and establish a connection to MTurk.
#
# A connection is made to production or to the sandbox based on values in the config.

# %%
import datetime
import boto3
import json
import copy
import pprint
from bs4 import BeautifulSoup as bs 
from uuid import uuid4
import csv
import os

# %%
# path to the config file 
CONFIG_PATH = "../config.json"

# where to save downloaded results 
SAVE_PATH = "assignments.json" 

# AWS profile to use
AWS_PROFILE_NAME = "memento"

# %%
USING_PROD = None
EXTERNAL_SUBMIT = None

# Read config and extract relevant settings
with open(CONFIG_PATH, 'r') as f:
    config = json.loads(f.read())
    
hit_config = config['hitCreation']

EXTERNAL_SUBMIT = config['advanced']['externalSubmit']

# Connection to production or sandbox 
if hit_config['production']:
    print("USING PROD")
    USING_PROD = True
    endpoint_url = 'https://mturk-requester.us-east-1.amazonaws.com'
    origin="production"
else:
    print("USING SANDBOX")
    USING_PROD = False
    endpoint_url = 'https://mturk-requester-sandbox.us-east-1.amazonaws.com'
    origin="sandbox"
    
hit_url = hit_config['taskUrl']
# If using an external link, add a querystring origin=sandbox or origin=production 
# for use in your js logic if you want. Not done for MTurk submits because it breaks the submit link
if (config['advanced']['externalSubmit']): 
    hit_url = "%s?origin=%s" % (hit_url, origin)
    
# Create an API connection
session = boto3.session.Session(profile_name=AWS_PROFILE_NAME)
cl = session.client('mturk', region_name='us-east-1', endpoint_url=endpoint_url)

print("Configuring task as external link with data submitted to: %s" % config['advanced']['externalSubmitUrl'] if EXTERNAL_SUBMIT else "Configuring task as an iframe within Mturk")
print("TASK URL: " + hit_url)
# Out:
# USING PROD
# Configuring task as an iframe within Mturk
# TASK URL: https://memento-game.csail.mit.edu/

# %% [markdown]
# # Make new HIT

# %%
# Safety flags that prevent you from accidentally messing up your HITs. 
# Set to False except when you are performing these specific tasks. 
ALLOW_HIT_CREATION = True
ALLOW_ASSIGNMENT_ADDITION = False
ALLOW_CREATE_QUAL = True
ALLOW_UPDATE_EXPIRATION = False

# %%
# List of qualifications that you will use to filter potential workers. 
# These require that workers come from the US and have an approval rating >= 95%
# Edit this list to specify different qualifications for workers 
QUALS = [
       {
           'QualificationTypeId': '00000000000000000071',
           'Comparator': 'EqualTo',
           'LocaleValues': [{
               'Country': 'US',
           }],
       },
        
       {
           'QualificationTypeId': '000000000000000000L0',
           'Comparator': 'GreaterThanOrEqualTo',
           'IntegerValues': [
               95
           ],
       },
    ]

# %%
# Helpers for creating HITs. 

# generic helper that sets metadata fields based on the config file.
def create_hit(task, questionText, quals=QUALS): 
    response = cl.create_hit(
        MaxAssignments=task['numAssignments'],
        AutoApprovalDelayInSeconds=604800,
        LifetimeInSeconds=task['lifetime'],
        AssignmentDurationInSeconds=task['duration'],
        Reward=task['rewardAmount'],
        Title=task['title'],
        Keywords=task['keywords'],
        Description=task['description'],
        Question=questionText,
        QualificationRequirements=quals,
    )
    print(response)
    print("\n")

# creates a HIT in the form of an External Question inside an iFrame
def create_hit_iframe(task):
    questionText = "<ExternalQuestion xmlns=\"http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/"
    questionText += "2006-07-14/ExternalQuestion.xsd\">\n<ExternalURL>" + task['taskUrl']
    questionText += "</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>"
    create_hit(task, questionText)
    
# Helper to create a HIT in the form of a simple UI with a link to an external page and an
# input box for a completion code 
def create_hit_external(task):
    with open('questionform_template.xml', 'r') as myfile:
        template=myfile.read() 
    question_xml = template % (hit_config["title"], hit_config["description"], task['taskUrl'])
    create_hit(task, question_xml)

# %%
# Use this cell to launch your HIT! 
if ALLOW_HIT_CREATION: 
    if not (hit_config.get('variants', False) or hit_config.get('numTasks', False)): 
        raise RuntimeError("You must specify either hitCreation.numTasks or hitCreation.variants in your config.json file")
    
    hit_creation_function = create_hit_external if EXTERNAL_SUBMIT else create_hit_iframe
    
    if hit_config.get('numTasks', False): 
        print("creating " + str(hit_config['numTasks']) + " tasks")
        for i in range(hit_config['numTasks']):
            hit_creation_function(hit_config)
    else: 
        print("creating " + str(len(config['variants'])) + " variants")
        for var in hit_config['variants']: 
            task = copy.deepcopy(config)
            task.update(var)
            hit_creation_function(task)
else: 
    raise RuntimeError("This action is not currently enabled; set `ALLOW_HIT_CREATION` to true to proceed with this action")

# %% [markdown]
# # HIT monitoring helpers

# %% [markdown]
# Helper functions that will be useful for monitoring the status of your HIT. See next section for how to use them.

# %%
# Contacts MTurk API to get all assignments for a HIT
# Returns them in a list. 
def get_all_assignments(hitid): 
    assignments = []
    should_continue = True
    next_token = False
    while (should_continue): 
        args = {
            'HITId': hitid, 
            'MaxResults': 100
        }
        if (next_token): 
            args['NextToken'] = next_token
        r = cl.list_assignments_for_hit(**args)
        next_token = r.get('NextToken', False)
        assignments.extend(r["Assignments"])
        should_continue = len(r["Assignments"]) > 0
    return assignments

# Summarizes all hits in `hits` in a human-readable way. 
# Prints out the HIT Title, id, if it is expired, and how many assignments it has
# completed, pending, and left for work. 
def summarize_hits(hits): 
    print(len(hits))
    ret = ""
    for hit in hits: 
        expiration = hit['Expiration'].replace(tzinfo=None)
        is_expired = expiration < datetime.datetime.now()
        description = ("Title: {title}\n" 
        "ID: {hid}\n"
        "\tAssignments left: {left}\n"
        "\tAssignments completed: {complete}\n"
        "\tAssignments pending: {pending}\n"
        "\tExpired: {exp}\n\n").format(
            title=hit['Title'], 
            hid=hit['HITId'], 
            left=hit['NumberOfAssignmentsAvailable'], 
            complete=hit['NumberOfAssignmentsCompleted'], 
            pending=hit['NumberOfAssignmentsPending'],
            exp=str(is_expired)
        )
        ret += description
    print(ret)
    
# Prints a human-readable summary of all pending/submitted/approved assignments for all hits in `hits`
def summarize_assignments(hits):
    ret = ""
    for hit in hits: 
        hid = hit['HITId']
        title =  hit['Title']
        name = "HIT %s: %s" % (hid, title)
        ret += name + "\n"
        assignments = get_all_assignments(hid)
        if len(assignments) == 0: 
            ret += "\tNo pending/submitted/approved assignments for this HIT\n"
        for a in assignments: 
            desc = "\tAssignment {aid}\n\t\tStatus: {status}\n".format(aid=a['AssignmentId'], status=a['AssignmentStatus'])
            ret += desc
    print(ret)
    
# Refreshes data about the requested hits
def refresh_hits(): 
    global hits 
    global MAX_RESULTS
    hits = cl.list_hits(MaxResults=MAX_RESULTS)['HITs']

# %% [markdown]
# # HIT monitoring

# %%
MAX_RESULTS = 100 # set equal to the number of outstanding hits you have 

# API call to grab HIT data from MTurk 
hits = cl.list_hits(MaxResults=MAX_RESULTS)['HITs']

# %%
# Summarizes all outstanding HITs
refresh_hits()
summarize_hits(hits)
# Out:
# 100
# Title: Compensation for HIT 3CL9ACF21N3XOSJBS5A8GX3DPU6W65
# ID: 3TX9T2ZCBBGY725AC5X93DBSXWJZWL
# 	Assignments left: 0
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3G9UA71JVX9TH8Z5MBMBN3OLL60J7J
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3MIVREZQVJDYYAA20VVTO95T5LSQKN
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 322ZSN9Z5IZQCODRW728MXRKS61T4E
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3U74KRR67O0CYWNXECH4L6XKJNWNT3
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3TLFH2L6YB3G9AY4STJKTIUM8S62TS
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 38DCH97KHJH3NQ4KIAVHNU5GQWSQJO
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3FTID4TN8NDIRIJ6C5OOGVLATUEYL1
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3VAOOVPI317YRJC7TQZYMNJEKFALLW
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3AA88CN98RI77C1OR5CN1V8V4U9YKY
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3XQ4XW3ODBRFUALP3TEUJDY069S2S3
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3YCT0L9OMOOBJWAIPCCEB11YH4INSE
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3XU9MCX6VQR3TVLCO4EPT3T4K792RF
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3TLFH2L6YB3G9AY4STJKTIUM8S5T2I
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3X7837UUAFDAD8L031HJHPOPQVGJ6K
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3W5PY7V3URMCWSV69KCB0G8IP59YJZ
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3X2YVV51PWJ1C6K24UOHBJRGKG9W1U
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3DA79LNS5BA5USUNWTXPCSZEE65T3T
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 38F60IALAIW9D0VQD6F6AU17BULT0Y
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3O4VWC1GEYLBGPYIKZJLAMC5G4EJ3E
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 35O6H0UNLUVEU4LMYI7EPJAPU05J54
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3DWNFENNE5AWYLHMKDO4KR4BU4AJ4Z
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3QREJ3J435CN7DUP8QNX7N6ZVF5LKT
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 371Q3BEXDJO50LO1S0N86O87RIQSZ0
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 371QPA24C439KPG89PJ6OZKHGMRT11
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3JUDR1D0D863HU6CBPPPODJZOL72QE
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3KG2UQJ0ML3Z6GV5X8N9G1MXZGXNQP
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3YGYP13643OZIHA5ANC9LRW2V2ZNRQ
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 38Z7YZ2SB5H7SFKE0SAHBTQGDH3QIC
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3CMV9YRYP5GSWTO7Q5NL686MGQ5LJU
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 34ZTTGSNJZ37WK9UUASWBHP1D4OQHJ
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 39RRBHZ0AWGLSD55MVSDHBSEQMKVZ8
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3WRKFXQBODMG1HB0R2RBOFTICQKYIN
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3PGQRAZX04Z5VVEWWELPSHZ5LOMSY9
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3YGE63DINAC15HZK8BKHXE86FO3W0R
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3C8QQOM6JRGW1I418N2LU7RM3BGLII
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 34F34TZU7YEMV72ZGZ5GRC7DAQEJ23
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 388CL5C1RL2W5NTH25K0UVQ73Y1LHP
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3DGDV62G7QOIHI5XBCA0O8TPJPL2PN
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3J9UN9O9J57FZXZL1C128OEYDSUJ0J
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3E22YV8GG3LE64UQXV8KGWWNUKBNPY
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3R6RZGK0XHRLNNV0Q9QU34JCKSGVYH
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3IVEC1GSLREF6MK3XV52MTX8IK0J1M
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3P4C70TRMTWI5RY6IZ2I9VE6OYOLGQ
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3MWOYZD5WX3WL4IPIVV5RWRXKFFNOH
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3LVTFB9DE7XTWOEJA4AEQHD0Y4BQGK
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3TL87MO8CO4CRR2B7FW0RAEUNJOLFR
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3H4IKZHALDXE3JIDHGVSC7RSU5ANN2
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3SR6AEG6W78G5M0GLK9QO3S3CD5YHU
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3JY0Q5X05LL2JZK57852W39YSH2GGF
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 39O6Z4JLX4CWNI5QLD4SKQC3IMMVXB
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3PCPFX4U425NIOIOZK4W8WDOXPBQFL
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3ECKRY5B1SBG67L5NOTU2M2KIKOIZY
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3EAWOID6MVCOQSZFI1FLBCPS8F20VM
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3WRKFXQBODMG1HB0R2RBOFTICQKIY7
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 37Y5RYYI0RKGVQOMRIZN93SWJISSX3
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 336OE47KI4ZHYI00B886I7YW9KGVWI
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3NFWQRSHVGTW5ZOAWOZKEI9MR22GFG
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 37G6BXQPLS0VCAIS49KQQESOLOWQE3
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 31GN6YMHLR716QJWHD317KEPAGMSWA
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 33QQ60S6AUXODDAFDB5GFQN9U8T0UX
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 39N6W9XWRF225Q551ER833G2XDSYGV
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3BPP3MA3TEZKLD2FC4CU9STUBI9LE9
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 38RHULDV90UCCCG0C19N3I821IKIW8
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3J06WJ78HPZ4JT0VLY3AW5FI2BEVV8
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3MYASTQBG9QQK44S8E96KWA3LCVQDA
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3E9ZFLPWO07R1CLQM65951M9AKQIX1
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 35JDMRECC6O4ZLOE1DFEW0OMF1NGEY
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 38G0E1M85OK46EBVG8T50JDZO45VUJ
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 38F60IALAIW9D0VQD6F6AU17BUM0T6
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3K1H3NEY7NEZ7FAE5I4UQI61FPMGD5
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3OLZC0DJ8LUZXNGVMR4RHGPOU9IIVY
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3CKVGCS3PIK8Y0IBO6AG0P5L9B80SH
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3D42WVSDHAAWRQ9AQULQLIGQWYSYFW
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3V8JSVE8Y054LC9EVJ1K30VQKXDYEE
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3Q7TKIAPOVPFT7OFG91A3AB9B68LDG
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3VGZ74AYTIVP2N405M9J6COJUPAGC5
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3OREP8RUT4Q6SICURMDOVSI1C4AGBY
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3XDSWAMB247GFCYE8IEV0QSL0CJQCA
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3OKP4QVBP4C19872L8DS0HYVUMPGA3
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3D5G8J4N5CJP61W6G33VVNRX5QYVTS
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3QO7EE372Q2X5768UII0P6M3IRJQB3
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3UXQ63NLAC1MEAQV2DA48KN98LWLB9
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3UQ1LLR26CNHV0L3WZA8D933Q3BLAE
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 31MBOZ6PAQ65OFI1GD6ZJ4TRQ6WLCG
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3AQN9REUTHVZT6VEZOQ0XID5KLCYDL
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 37ZQELHEQ2D8L1XD5FGSZS2SPF0NM2
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3HA5ODM5KC7OR1JRR3Y5LIVB37KVS3
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3HKIF5DF60CN4PXXT2ZS4MNBO47G9O
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3HA5ODM5KC7OR1JRR3Y5LIVB37KSV0
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3NQUW096N8N3QHBY4TW8HESJKLTL9Z
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3VDI8GSXAH8NQKENOATE4QS04YPG8Z
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3OPLMF3EU72OFJFS53FDZFN3PAANL0
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3QHITW7OYQOSMX1GO4I4UV2X09YQA8
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3D1TUISJWKFZK8RVH1UMLUN5G29IU9
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3L55D8AUFCCPOEP0ZSVPDCVNZL0YCL
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3HEADTGN2R7CQMJECEY0V8QFH51VRF
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3IQ9O0AYW8EKKVC6HW4CGY13XO2ITI
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 31JUPBOORPJ3CCSOZ1QUHIX80FBL8A
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Memento: The Video Memory Game
# ID: 3CO05SML7XKWXLIY9HABAF0PN9P0RT
# 	Assignments left: 0
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False

# %%
# Summarizes assignments for all oustanding HITs 
refresh_hits()
summarize_assignments(hits)
# Out:
# HIT 3TX9T2ZCBBGY725AC5X93DBSXWJZWL: Compensation for HIT 3CL9ACF21N3XOSJBS5A8GX3DPU6W65
# 	Assignment 3JCG6DTRV65MWX6R32KR8FCQGWFQQB
# 		Status: Submitted
# HIT 3G9UA71JVX9TH8Z5MBMBN3OLL60J7J: Memento: The Video Memory Game
# 	Assignment 3QXNC7EIPLASG5K652FQ7EVJSN609J
# 		Status: Approved
# HIT 3MIVREZQVJDYYAA20VVTO95T5LSQKN: Memento: The Video Memory Game
# 	Assignment 3EFE17QCRFKLWKM1CGM2U1ZQ6SRSHI
# 		Status: Approved
# HIT 322ZSN9Z5IZQCODRW728MXRKS61T4E: Memento: The Video Memory Game
# 	Assignment 32KTQ2V7RGUPJJRDU72O5B2WVQ29MY
# 		Status: Approved
# HIT 3U74KRR67O0CYWNXECH4L6XKJNWNT3: Memento: The Video Memory Game
# 	Assignment 3PH3VY7DJOC0UM34272ARX6G8V4WZR
# 		Status: Approved
# HIT 3TLFH2L6YB3G9AY4STJKTIUM8S62TS: Memento: The Video Memory Game
# 	Assignment 3570Y55XZSY4SA3ZRGW9RNBQ8DBGYM
# 		Status: Approved
# HIT 38DCH97KHJH3NQ4KIAVHNU5GQWSQJO: Memento: The Video Memory Game
# 	Assignment 3PH3VY7DJOC0UM34272ARX6G8V4ZWU
# 		Status: Approved
# HIT 3FTID4TN8NDIRIJ6C5OOGVLATUEYL1: Memento: The Video Memory Game
# 	Assignment 37W3JXSD69N0PWTZ6L0RDQXE210WY0
# 		Status: Approved
# HIT 3VAOOVPI317YRJC7TQZYMNJEKFALLW: Memento: The Video Memory Game
# 	Assignment 3OF2M9AATJ39ZM9NDTJ73MCLLO0KZO
# 		Status: Approved
# HIT 3AA88CN98RI77C1OR5CN1V8V4U9YKY: Memento: The Video Memory Game
# 	Assignment 3WEV0KO0OP74K4HZQK3C3GKSE0YSD9
# 		Status: Approved
# HIT 3XQ4XW3ODBRFUALP3TEUJDY069S2S3: Memento: The Video Memory Game
# 	Assignment 3V5Q80FXI06DXDY43GIUZPLCPTB23J
# 		Status: Approved
# HIT 3YCT0L9OMOOBJWAIPCCEB11YH4INSE: Memento: The Video Memory Game
# 	Assignment 3LYA37P8IT2DHO677F34H45IUL9KBD
# 		Status: Approved
# HIT 3XU9MCX6VQR3TVLCO4EPT3T4K792RF: Memento: The Video Memory Game
# 	Assignment 3YMTUJH0DVVSZ8BLM979AHM836KT4N
# 		Status: Approved
# HIT 3TLFH2L6YB3G9AY4STJKTIUM8S5T2I: Memento: The Video Memory Game
# 	Assignment 3IAEQB9FMHZXRLY8APDD05NDKD6DWL
# 		Status: Approved
# HIT 3X7837UUAFDAD8L031HJHPOPQVGJ6K: Memento: The Video Memory Game
# 	Assignment 3AMW0RGHOGHGTOSKNXDL4GRB5KTPN8
# 		Status: Approved
# HIT 3W5PY7V3URMCWSV69KCB0G8IP59YJZ: Memento: The Video Memory Game
# 	Assignment 3C6FJU71TT8NXS4UBLLQV2CHHLPUYZ
# 		Status: Approved
# HIT 3X2YVV51PWJ1C6K24UOHBJRGKG9W1U: Memento: The Video Memory Game
# 	Assignment 3XM0HYN6NNECZIF7UYA2ETX2RSSPEJ
# 		Status: Approved
# HIT 3DA79LNS5BA5USUNWTXPCSZEE65T3T: Memento: The Video Memory Game
# 	Assignment 3E7TUJ2EGF1MFPL0HE3LMLF2MC89DE
# 		Status: Approved
# HIT 38F60IALAIW9D0VQD6F6AU17BULT0Y: Memento: The Video Memory Game
# 	Assignment 3UNH76FOCVK4KKZL2JU44SVN4ZMMYZ
# 		Status: Approved
# HIT 3O4VWC1GEYLBGPYIKZJLAMC5G4EJ3E: Memento: The Video Memory Game
# 	Assignment 3DYGAII7PON1WL5C3P528AMGAVGPQV
# 		Status: Approved
# HIT 35O6H0UNLUVEU4LMYI7EPJAPU05J54: Memento: The Video Memory Game
# 	Assignment 3I0BTBYZA007H6SEDE766VOA1W10YI
# 		Status: Approved
# HIT 3DWNFENNE5AWYLHMKDO4KR4BU4AJ4Z: Memento: The Video Memory Game
# 	Assignment 32Z9ZLUT1OZ6YSU85Z5TAWPP93OHOA
# 		Status: Approved
# HIT 3QREJ3J435CN7DUP8QNX7N6ZVF5LKT: Memento: The Video Memory Game
# 	Assignment 3H7Z272LXAMQ5OPZBKX6RONM0PULP3
# 		Status: Approved
# HIT 371Q3BEXDJO50LO1S0N86O87RIQSZ0: Memento: The Video Memory Game
# 	Assignment 3GD6L00D3VC7UEOIQUNVQ5KDXEEM12
# 		Status: Approved
# HIT 371QPA24C439KPG89PJ6OZKHGMRT11: Memento: The Video Memory Game
# 	Assignment 3B1NLC6UG2BAJWBY0T0QEWIE487PG0
# 		Status: Approved
# HIT 3JUDR1D0D863HU6CBPPPODJZOL72QE: Memento: The Video Memory Game
# 	Assignment 3IAS3U3I0IVI082HI9X0H8JODLO2BA
# 		Status: Approved
# HIT 3KG2UQJ0ML3Z6GV5X8N9G1MXZGXNQP: Memento: The Video Memory Game
# 	Assignment 3EG49X351XRDVCOJA71LWIRSCTDX6U
# 		Status: Approved
# HIT 3YGYP13643OZIHA5ANC9LRW2V2ZNRQ: Memento: The Video Memory Game
# 	Assignment 3OE22WJIGL3EOQD8KB4WIG9FICJUQ7
# 		Status: Approved
# HIT 38Z7YZ2SB5H7SFKE0SAHBTQGDH3QIC: Memento: The Video Memory Game
# 	Assignment 3EFE17QCRFKLWKM1CGM2U1ZQ6STSHK
# 		Status: Approved
# HIT 3CMV9YRYP5GSWTO7Q5NL686MGQ5LJU: Memento: The Video Memory Game
# 	Assignment 3IXEICO795Y6EVFZ5X0O7F6MZXQ6TL
# 		Status: Approved
# HIT 34ZTTGSNJZ37WK9UUASWBHP1D4OQHJ: Memento: The Video Memory Game
# 	Assignment 37Q970SNZHNAS91NARJH2EJJP3W1ST
# 		Status: Approved
# HIT 39RRBHZ0AWGLSD55MVSDHBSEQMKVZ8: Memento: The Video Memory Game
# 	Assignment 30LSNF239XASNGGNOJPH3VN18BMI2D
# 		Status: Approved
# HIT 3WRKFXQBODMG1HB0R2RBOFTICQKYIN: Memento: The Video Memory Game
# 	Assignment 3ZAZR5XV04XRGOXZLG29F3ZDGFFZCE
# 		Status: Approved
# HIT 3PGQRAZX04Z5VVEWWELPSHZ5LOMSY9: Memento: The Video Memory Game
# 	Assignment 3VBEN272MNE7WORQSA4K91NPRSESGJ
# 		Status: Approved
# HIT 3YGE63DINAC15HZK8BKHXE86FO3W0R: Memento: The Video Memory Game
# 	Assignment 31IBVUNM9VEHAGCZBL37237KPH8VFS
# 		Status: Approved
# HIT 3C8QQOM6JRGW1I418N2LU7RM3BGLII: Memento: The Video Memory Game
# 	Assignment 3I33IC7ZWIHDHYXPCVX4MXZIV4NA29
# 		Status: Approved
# HIT 34F34TZU7YEMV72ZGZ5GRC7DAQEJ23: Memento: The Video Memory Game
# 	Assignment 31N2WW6R9U5XY7AGRBX1J8F1YXQF3Q
# 		Status: Approved
# HIT 388CL5C1RL2W5NTH25K0UVQ73Y1LHP: Memento: The Video Memory Game
# 	Assignment 3D8YOU6S9HZLE8UO52QYCBSOIBX6UC
# 		Status: Approved
# HIT 3DGDV62G7QOIHI5XBCA0O8TPJPL2PN: Memento: The Video Memory Game
# 	Assignment 373ERPL3YRNZ0EDJXL3MIAXIVKGTRI
# 		Status: Approved
# HIT 3J9UN9O9J57FZXZL1C128OEYDSUJ0J: Memento: The Video Memory Game
# 	Assignment 3IFS6Q0HJLYLSFXLIY4NUD05658SID
# 		Status: Approved
# HIT 3E22YV8GG3LE64UQXV8KGWWNUKBNPY: Memento: The Video Memory Game
# 	Assignment 3DHE4R9OCZQERPASYVPEIJALTYG2GR
# 		Status: Approved
# HIT 3R6RZGK0XHRLNNV0Q9QU34JCKSGVYH: Memento: The Video Memory Game
# 	Assignment 3C44YUNSI4477C17Y3ZI8BFHRGRPDQ
# 		Status: Approved
# HIT 3IVEC1GSLREF6MK3XV52MTX8IK0J1M: Memento: The Video Memory Game
# 	Assignment 3OVHNO1VE9G1LG3DLCXKZ9HV1F1DZ2
# 		Status: Approved
# HIT 3P4C70TRMTWI5RY6IZ2I9VE6OYOLGQ: Memento: The Video Memory Game
# 	Assignment 3QIYRE09Y6WDCW9I2V2V3K9D24NN12
# 		Status: Approved
# HIT 3MWOYZD5WX3WL4IPIVV5RWRXKFFNOH: Memento: The Video Memory Game
# 	Assignment 3QAPZX2QN7SHGLZ7KT0BXRN5MHR20O
# 		Status: Approved
# HIT 3LVTFB9DE7XTWOEJA4AEQHD0Y4BQGK: Memento: The Video Memory Game
# 	Assignment 3WQ3B2KGEBVBBNKLZ5XMCP9JLFAB12
# 		Status: Approved
# HIT 3TL87MO8CO4CRR2B7FW0RAEUNJOLFR: Memento: The Video Memory Game
# 	Assignment 3AQF3RZ55BXWVQXYADVZQBRL8PY6FV
# 		Status: Approved
# HIT 3H4IKZHALDXE3JIDHGVSC7RSU5ANN2: Memento: The Video Memory Game
# 	Assignment 3CP1TO84PWGGBSL8HZ6NEMJW3P2259
# 		Status: Approved
# HIT 3SR6AEG6W78G5M0GLK9QO3S3CD5YHU: Memento: The Video Memory Game
# 	Assignment 354GIDR5ZELAKBWT56WXE3UQPJ7002
# 		Status: Approved
# HIT 3JY0Q5X05LL2JZK57852W39YSH2GGF: Memento: The Video Memory Game
# 	Assignment 3YJ6NA41JEVKAY1Z8ZLTB9AUW0OPJ4
# 		Status: Approved
# HIT 39O6Z4JLX4CWNI5QLD4SKQC3IMMVXB: Memento: The Video Memory Game
# 	Assignment 3Z4XG4ZF4B60ZQ773MYJGWNJIO3X8G
# 		Status: Approved
# HIT 3PCPFX4U425NIOIOZK4W8WDOXPBQFL: Memento: The Video Memory Game
# 	Assignment 3ZSANO2JCIM1IOVVHQY2RGNDQDESFK
# 		Status: Approved
# HIT 3ECKRY5B1SBG67L5NOTU2M2KIKOIZY: Memento: The Video Memory Game
# 	Assignment 3Z2R0DQ0JKTG7BE1S0ZQIGP9GI12EA
# 		Status: Approved
# HIT 3EAWOID6MVCOQSZFI1FLBCPS8F20VM: Memento: The Video Memory Game
# 	Assignment 3VNXK88KKFX896LM8Z3FS7L9MJDV90
# 		Status: Approved
# HIT 3WRKFXQBODMG1HB0R2RBOFTICQKIY7: Memento: The Video Memory Game
# 	Assignment 3EG49X351XRDVCOJA71LWIRSCTE6X4
# 		Status: Approved
# HIT 37Y5RYYI0RKGVQOMRIZN93SWJISSX3: Memento: The Video Memory Game
# 	Assignment 3YMU66OBIQNI6FDAHGSL5NGNIHTGHI
# 		Status: Approved
# HIT 336OE47KI4ZHYI00B886I7YW9KGVWI: Memento: The Video Memory Game
# 	Assignment 339ANSOTR8HN4WKDDPVL3R9VPBTKIM
# 		Status: Approved
# HIT 3NFWQRSHVGTW5ZOAWOZKEI9MR22GFG: Memento: The Video Memory Game
# 	Assignment 39GXDJN2OWT8V12C37X1SBQY2DVV8B
# 		Status: Approved
# HIT 37G6BXQPLS0VCAIS49KQQESOLOWQE3: Memento: The Video Memory Game
# 	Assignment 3ZV9H2YQQGMZ9TWBH071NW11T0T3WP
# 		Status: Approved
# HIT 31GN6YMHLR716QJWHD317KEPAGMSWA: Memento: The Video Memory Game
# 	Assignment 3R6BYFZZPAR9E5HUB04PQO455SHXFY
# 		Status: Approved
# HIT 33QQ60S6AUXODDAFDB5GFQN9U8T0UX: Memento: The Video Memory Game
# 	Assignment 3B2X28YI3ZU6I9LI5B937L00TQZ6B4
# 		Status: Approved
# HIT 39N6W9XWRF225Q551ER833G2XDSYGV: Memento: The Video Memory Game
# 	Assignment 3QILPRALQ8AVNWT31GBAIUWLGATN8M
# 		Status: Approved
# HIT 3BPP3MA3TEZKLD2FC4CU9STUBI9LE9: Memento: The Video Memory Game
# 	Assignment 3C2NJ6JBKDWK1HRELZ2983JIUA1N2J
# 		Status: Approved
# HIT 38RHULDV90UCCCG0C19N3I821IKIW8: Memento: The Video Memory Game
# 	Assignment 3AUQQEL7U88QDCX983KMZWKGJFJV0O
# 		Status: Approved
# HIT 3J06WJ78HPZ4JT0VLY3AW5FI2BEVV8: Memento: The Video Memory Game
# 	Assignment 3SITXWYCNYOJ1O5E6YIT7YDKQUOXBF
# 		Status: Approved
# HIT 3MYASTQBG9QQK44S8E96KWA3LCVQDA: Memento: The Video Memory Game
# 	Assignment 3C2NJ6JBKDWK1HRELZ2983JIUAD2NA
# 		Status: Approved
# HIT 3E9ZFLPWO07R1CLQM65951M9AKQIX1: Memento: The Video Memory Game
# 	Assignment 3EJPLAJKEPV207OYBPP6T373KTC6Z1
# 		Status: Approved
# HIT 35JDMRECC6O4ZLOE1DFEW0OMF1NGEY: Memento: The Video Memory Game
# 	Assignment 3HHRAGRYXBKDJMCP7NH1XFR1QQHO9S
# 		Status: Approved
# HIT 38G0E1M85OK46EBVG8T50JDZO45VUJ: Memento: The Video Memory Game
# 	Assignment 3RU7GD8VPR8D91KPVTU73A1HSKRPSC
# 		Status: Approved
# HIT 38F60IALAIW9D0VQD6F6AU17BUM0T6: Memento: The Video Memory Game
# 	Assignment 3FPRZHYEP1MMU4W6RQ251UINMR3V3J
# 		Status: Approved
# HIT 3K1H3NEY7NEZ7FAE5I4UQI61FPMGD5: Memento: The Video Memory Game
# 	Assignment 3GNCZX450L2995YVET8GIA7B6DVAPA
# 		Status: Approved
# HIT 3OLZC0DJ8LUZXNGVMR4RHGPOU9IIVY: Memento: The Video Memory Game
# 	Assignment 3KXIR214I7VYF9H83UND9UDI3T7426
# 		Status: Approved
# HIT 3CKVGCS3PIK8Y0IBO6AG0P5L9B80SH: Memento: The Video Memory Game
# 	Assignment 34MAJL3QP72N0RDR7U1IS4IA97743H
# 		Status: Approved
# HIT 3D42WVSDHAAWRQ9AQULQLIGQWYSYFW: Memento: The Video Memory Game
# 	Assignment 3TOK3KHVJWX953OWSQJHJJ0VV0T7OZ
# 		Status: Approved
# HIT 3V8JSVE8Y054LC9EVJ1K30VQKXDYEE: Memento: The Video Memory Game
# 	Assignment 3L6L49WXW3CQE60VLDPB71GUN3Y457
# 		Status: Approved
# HIT 3Q7TKIAPOVPFT7OFG91A3AB9B68LDG: Memento: The Video Memory Game
# 	Assignment 3MX2NQ3YCC9HC8O55ORG4CDSGY2X5E
# 		Status: Approved
# HIT 3VGZ74AYTIVP2N405M9J6COJUPAGC5: Memento: The Video Memory Game
# 	Assignment 3IUZPWIU1RM55R4I26Z04II34MSKWU
# 		Status: Approved
# HIT 3OREP8RUT4Q6SICURMDOVSI1C4AGBY: Memento: The Video Memory Game
# 	Assignment 308XBLVESLJZ4SJ2XZC1IGRWPD4RBE
# 		Status: Approved
# HIT 3XDSWAMB247GFCYE8IEV0QSL0CJQCA: Memento: The Video Memory Game
# 	Assignment 3PIWWX1FJMLOONY1DMG9EDOIN1VJJB
# 		Status: Approved
# HIT 3OKP4QVBP4C19872L8DS0HYVUMPGA3: Memento: The Video Memory Game
# 	Assignment 39L1G8WVWT668SG8KCIGU6B7XNG31M
# 		Status: Approved
# HIT 3D5G8J4N5CJP61W6G33VVNRX5QYVTS: Memento: The Video Memory Game
# 	Assignment 3TESA3PJ34P4Q3A7JG6TAX8GVPZMM0
# 		Status: Approved
# HIT 3QO7EE372Q2X5768UII0P6M3IRJQB3: Memento: The Video Memory Game
# 	Assignment 37ZHEEHM6Z1KJEVA9SZPVG2K09Y735
# 		Status: Approved
# HIT 3UXQ63NLAC1MEAQV2DA48KN98LWLB9: Memento: The Video Memory Game
# 	Assignment 3X4MXAO0BJ3RSVHDSQ8X5U4HZELRWT
# 		Status: Approved
# HIT 3UQ1LLR26CNHV0L3WZA8D933Q3BLAE: Memento: The Video Memory Game
# 	Assignment 3LS2AMNW5I5JBLTBOPSNJAHQ0QLOQE
# 		Status: Approved
# HIT 31MBOZ6PAQ65OFI1GD6ZJ4TRQ6WLCG: Memento: The Video Memory Game
# 	Assignment 3RYC5T2D76818MKCG4U2D0WL6HNPR1
# 		Status: Approved
# HIT 3AQN9REUTHVZT6VEZOQ0XID5KLCYDL: Memento: The Video Memory Game
# 	Assignment 39JEC7537XGA74SPKJD6UXMHS4GVCH
# 		Status: Approved
# HIT 37ZQELHEQ2D8L1XD5FGSZS2SPF0NM2: Memento: The Video Memory Game
# 	Assignment 3WI0P0II647SJPHMBV37D6FWSYBRDG
# 		Status: Approved
# HIT 3HA5ODM5KC7OR1JRR3Y5LIVB37KVS3: Memento: The Video Memory Game
# 	Assignment 36TFCYNS47PTS1806QSPT9GIL7TXHV
# 		Status: Approved
# HIT 3HKIF5DF60CN4PXXT2ZS4MNBO47G9O: Memento: The Video Memory Game
# 	Assignment 3LUY3GC632FRQ30X7QWW8J5L55OP7X
# 		Status: Approved
# HIT 3HA5ODM5KC7OR1JRR3Y5LIVB37KSV0: Memento: The Video Memory Game
# 	Assignment 3RKNTXVS3PDNKCCCG9GSFCWGFHZ4AD
# 		Status: Approved
# HIT 3NQUW096N8N3QHBY4TW8HESJKLTL9Z: Memento: The Video Memory Game
# 	Assignment 3H7XDTSHKF60358ZCFEL6QQAX5PWGH
# 		Status: Approved
# HIT 3VDI8GSXAH8NQKENOATE4QS04YPG8Z: Memento: The Video Memory Game
# 	Assignment 3TESA3PJ34P4Q3A7JG6TAX8GVP8MM9
# 		Status: Approved
# HIT 3OPLMF3EU72OFJFS53FDZFN3PAANL0: Memento: The Video Memory Game
# 	Assignment 3TXWC2NHN25SHE4IE4YAHK12NFTS92
# 		Status: Approved
# HIT 3QHITW7OYQOSMX1GO4I4UV2X09YQA8: Memento: The Video Memory Game
# 	Assignment 3HYA4D452UY8DPEXNBJW0YA9SJG2FS
# 		Status: Approved
# HIT 3D1TUISJWKFZK8RVH1UMLUN5G29IU9: Memento: The Video Memory Game
# 	Assignment 3QILPRALQ8AVNWT31GBAIUWLGAU8N8
# 		Status: Approved
# HIT 3L55D8AUFCCPOEP0ZSVPDCVNZL0YCL: Memento: The Video Memory Game
# 	Assignment 3PPTZCWALTZVAP7IQY34Z8OUKUNZQQ
# 		Status: Approved
# HIT 3HEADTGN2R7CQMJECEY0V8QFH51VRF: Memento: The Video Memory Game
# 	Assignment 3GU1KF0O4LGESF3NK78CDLRHOVFPBJ
# 		Status: Approved
# HIT 3IQ9O0AYW8EKKVC6HW4CGY13XO2ITI: Memento: The Video Memory Game
# 	Assignment 30LSNF239XASNGGNOJPH3VN18BII29
# 		Status: Approved
# HIT 31JUPBOORPJ3CCSOZ1QUHIX80FBL8A: Memento: The Video Memory Game
# 	Assignment 3PZDLQMM0W01ADUNW9TVSSP6V7T2CO
# 		Status: Approved
# HIT 3CO05SML7XKWXLIY9HABAF0PN9P0RT: Memento: The Video Memory Game
# 	Assignment 3HMVI3QICM77OVDW9XB6K07K6O61YL
# 		Status: Approved

# %% [markdown]
# # Approve HITs

# %% [markdown]
# Approves all outstanding assignments for the HITs displayed above.

# %%
def approve_all(hits): 
    num_approved = 0
    for hit in hits: 
        # make sure you keep getting assignments 
        assignments = get_all_assignments(hit["HITId"])
#         print(assignments)
        for a in assignments: 
            if a['AssignmentStatus'] != 'Approved':
                print("Approving assignment")
                num_approved += 1
                cl.approve_assignment(AssignmentId=a['AssignmentId'])
    print("Approved %d assignments" % num_approved)

# def approve_all(assignments): 
#     for a in assignments: 
        
#         print(a)
#         cl.approve_assignment(AssignmentId=a['AssignmentId'])
#     print("Succesfully approved %d assignments" % len(assignments))

# %%
# refresh_hits()
approve_all(hits)
# Out:
# Approving assignment
# Approved 1 assignments

# %% [markdown]
# # Update expiration or num tasks

# %%
# changes the expiration date on a HIT to days_from_now days in the future
def update_expiration(hitid, days_from_now): 
    if ALLOW_UPDATE_EXPIRATION: 
        days = days_from_now*datetime.timedelta(days=1)
        expire_time = datetime.datetime.now() + days

        response = cl.update_expiration_for_hit(HITId=hitid, ExpireAt=expire_time)
        print(response)
        return response
    else: 
        raise RuntimeError("This action is not currently enabled; set `ALLOW_UPDATE_EXPIRATION` to true to proceed with this action")
    
def expire_hit(hit): 
    return update_expiration(hit, -10)

# %%
def add_assignments(hitid, num_assignments): 
    if ALLOW_ASSIGNMENT_ADDITION: 
        response = cl.create_additional_assignments_for_hit(
            HITId=hitid,
            NumberOfAdditionalAssignments=num_assignments
        )
        print(response)
        return response
    else: 
        raise RuntimeError("This action is not currently enabled; set `ALLOW_ASSIGNMENT_ADDITION` to true to proceed with this action")

# %%
# Use this cell to expire a HIT 
HIT_id_to_expire = "FILL THIS IN" 
expire_hit(HIT_id_to_expire)

# %%
# Use this cell to add assignments to a HIT 
HIT_id_to_add_assignments = "FILL THIS IN"
num_assignments_to_add = 0
add_assignments(HIT_id_to_add_assignments, num_assignments_to_add)

# %% [markdown]
# # Add custom qualifications

# %% [markdown]
# ## Add a qualification to disqualify workers who have done work before
#
# - uses "negative qualification" method from https://github.com/cloudyr/MturkR/wiki/qualifications-as-blocks
#
# #### NOTE: quals are kept separate for the sandbox and prod. Make sure you are creating and assigning your quals in prod.

# %% [markdown]
# ### Structure of a new qualification

# %%
NEW_QUAL = {
    'Name': 'qualName',
    'Keywords': 'Keywords for qual',
    'Description': 'What is this qual, and why are you assigning it?',
    'QualificationTypeStatus': 'Active',
    'AutoGranted': False
}

# %% [markdown]
# ### Helpers for creating, viewing, and assigning qualifications

# %%
# Registers a custom qualification with MTurk 
def create_qual(new_qual):
    if ALLOW_CREATE_QUAL: 
        response = cl.create_qualification_type(**new_qual)
        print(response)
        Id = response['QualificationType']['QualificationTypeId']
        print("id", Id)
        return Id
    else: 
        raise RuntimeError("This action is not currently enabled; set `ALLOW_CREATE_QUAL` to true to proceed with this action")
        
# Gets all the custom quals you have created and prints them
def list_quals(): 
    response = cl.list_qualification_types(
            Query='hasCompletedVisualGraphRecallTask',
            MustBeRequestable=False
    )
    print(response)
    
# Assigns a qualification to a worker 
def assign_qual(qual_id, worker_ids): 
    for worker in worker_ids: 
        response = cl.associate_qualification_with_worker(
                QualificationTypeId=qual_id, 
                WorkerId=worker,
                IntegerValue=1,
                SendNotification=False
        )
        print(response)
        assert response
        
# Gets the ids of all workers who worked on a particular hit 
def get_workers_for_hit(hitid): 
    a = get_all_assignments(hitid)
    workers = [a_['WorkerId'] for a_ in a]
    return workers
    
# Confirms that every worker in worker_ids has qual with qual_id
def confirm_quals(qual_id, worker_ids): 
    for w in worker_ids: 
        response = cl.get_qualification_score(
                QualificationTypeId=qual_id,
                WorkerId=w
        )
        response = response['Qualification']
        assert response['Status'] == 'Granted'
        assert response['IntegerValue'] == 1
        
# Assigns qual with `qual_id` to every worker who has completed an assignment for the hit with `hitid`
def assign_qual_for_hit(hitid, qual_id): 
    workers = get_workers_for_hit(hitid)
    print("got workers")
    assign_qual(qual_id, workers)
    print("assigned qual")
    confirm_quals(qual_id, workers)
    print("confirmed qual")

# %% [markdown]
# ### Use the following cells to manipulate qualifications

# %%
# Use this cell to view the custom qualifications you have created
list_quals()
# Out:
# {'NumResults': 1, 'NextToken': 'p1:ED0bhpuxe22XySiXhMYa/J9clZajTrFZpEPXmTXcf5yZX63OaialpqxaRHB34w==', 'QualificationTypes': [{'QualificationTypeId': '3Q3I6L0BKOF89DJMPYQCYLJBC2VW5E', 'CreationTime': datetime.datetime(2018, 3, 23, 17, 19, 7, tzinfo=tzlocal()), 'Name': 'hasCompletedVisualGraphRecallTask', 'Description': 'Assigned to people who have already completed work on a visual graph recall task. A worker can only complete this type of task once.', 'Keywords': 'Already completed visual graph recall task', 'QualificationTypeStatus': 'Active', 'IsRequestable': True, 'AutoGranted': False}], 'ResponseMetadata': {'RequestId': '32744d84-e7be-429e-bc9c-32d6e9723a3c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '32744d84-e7be-429e-bc9c-32d6e9723a3c', 'content-type': 'application/x-amz-json-1.1', 'content-length': '531', 'date': 'Thu, 07 Mar 2019 02:27:55 GMT'}, 'RetryAttempts': 0}}

# %%
# Use this cell to create a new qual 
qual_to_create = {}
create_qual(qual_to_create)

# %%
# Use this cell to assign a custom qual to every worker who has done a specific HIT
hit_id = "FILL THIS IN"
qual_id_to_assign = "FILL THIS IN"
assign_qual_for_hit(hit_id, qual_id_to_assign)

# %% [markdown]
# # Create Compensation HIT
#
# Mistakes happen, and sometimes they can lead to a worker who put in an honest effort being unable to complete a task and get paid. It's a good idea to compensate these workers when they reach out because it helps maintain relations with workers and is the right thing to do.
#
# However, workers can only be paid upon completing a task. The workaround is to create a custom qualification, assign it to the worker you want to compensate, and create a no-work HIT requiring the custom qualification. This code does that.

# %%
# worker_ids is str[]
# compensation is str but should match the regex ^\d*\.\d\d$ (e.g. "1.00")
# for_hit_id is str -- optional, but helpful for records
def compensate_workers(worker_ids, compensation, for_hit_id=""):
    with open('compensation.xml', 'r') as myfile:
        question_xml=myfile.read()

    keywords = 'compensation'
    description = 'Compensation for HIT'
    if for_hit_id:
        keywords += ', ' + for_hit_id
        description += ' ' + for_hit_id

    # create qual, assign to workers
    custom_qual = {
        'Name': str(uuid4()), # a qual must have a unique name
        'Keywords': keywords,
        'Description': description,
        'QualificationTypeStatus': 'Active',
        'AutoGranted': False
    }
    qual_id = create_qual(custom_qual)
    assign_qual(qual_id, worker_ids)

    # create HIT requiring qual
    task = {
        'numAssignments': len(worker_ids),
        'lifetime': 3 * 24 * 60 * 60, # 3 days
        'duration': 5 * 60, # 5 min
        'rewardAmount': compensation,
        'title': description,
        'keywords': keywords,
        'description': description,
    }
    quals = [{
        'QualificationTypeId': qual_id,
        'Comparator': 'Exists',
        'ActionsGuarded': 'DiscoverPreviewAndAccept'
    }]
    create_hit(task, question_xml, quals)

# %%
worker_ids = ['A2X977GVQ6L90X'] # worker_id strings in a list
compensation = "1.50" # change to the amount of dollars you want to give
for_hit_id = "3CL9ACF21N3XOSJBS5A8GX3DPU6W65" # hit_id string (what you are compensating for)
compensate_workers(worker_ids, compensation, for_hit_id)
# Out:
# {'QualificationType': {'QualificationTypeId': '3KPNUZIAIZLB24BL17JZMQ2QTJQ1HV', 'CreationTime': datetime.datetime(2019, 3, 6, 21, 33, 44, tzinfo=tzlocal()), 'Name': '8efb7505-3342-4670-a6e8-9323e316f1db', 'Description': 'Compensation for HIT 3CL9ACF21N3XOSJBS5A8GX3DPU6W65', 'Keywords': 'compensation, 3CL9ACF21N3XOSJBS5A8GX3DPU6W65', 'QualificationTypeStatus': 'Active', 'IsRequestable': True, 'AutoGranted': False}, 'ResponseMetadata': {'RequestId': '645db764-54c0-44e7-a6a6-d8f0a3a630f5', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '645db764-54c0-44e7-a6a6-d8f0a3a630f5', 'content-type': 'application/x-amz-json-1.1', 'content-length': '355', 'date': 'Thu, 07 Mar 2019 02:33:44 GMT'}, 'RetryAttempts': 0}}
# id 3KPNUZIAIZLB24BL17JZMQ2QTJQ1HV
# {'ResponseMetadata': {'RequestId': '07302522-a05f-4d2b-978c-008a0a971e24', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '07302522-a05f-4d2b-978c-008a0a971e24', 'content-type': 'application/x-amz-json-1.1', 'content-length': '2', 'date': 'Thu, 07 Mar 2019 02:33:45 GMT'}, 'RetryAttempts': 0}}
# {'HIT': {'HITId': '3TX9T2ZCBBGY725AC5X93DBSXWJZWL', 'HITTypeId': '3LC6UUY7PSRFLM86XK824DVTMDLDDJ', 'HITGroupId': '3SBA6YTBZ5NVPVR4XA06AJCJ0QJOB1', 'CreationTime': datetime.datetime(2019, 3, 6, 21, 33, 45, tzinfo=tzlocal()), 'Title': 'Compensation for HIT 3CL9ACF21N3XOSJBS5A8GX3DPU6W65', 'Description': 'Compensation for HIT 3CL9ACF21N3XOSJBS5A8GX3DPU6W65', 'Question': '<QuestionForm xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2005-10-01/QuestionForm.xsd">\n    <Overview>\n        <FormattedContent><![CDATA[\n            <h1><strong>Compensation HIT</strong></h1>\n            <h2>Description</h2>\n            <h4>We\'re sorry you experienced a problem with one of our HITs. Please accept our apologies and compensation for your time.</h4>\n            <h2>Instructions:</h2>\n            <h4>Enter your worker ID in the box below.</h4>\n        ]]>\n        </FormattedContent>\n    </Overview>\n    <Question>\n        <QuestionIdentifier>workerID</QuestionIdentifier>\n        <DisplayName>Worker ID</DisplayName>\n        <IsRequired>true</IsRequired>\n        <QuestionContent>\n            <Text>Please enter your worker ID here: </Text>\n        </QuestionContent>\n        <AnswerSpecification>\n            <FreeTextAnswer>\n                <NumberOfLinesSuggestion>1</NumberOfLinesSuggestion>\n            </FreeTextAnswer>\n        </AnswerSpecification>\n    </Question>\n</QuestionForm>\n', 'Keywords': 'compensation, 3CL9ACF21N3XOSJBS5A8GX3DPU6W65', 'HITStatus': 'Assignable', 'MaxAssignments': 1, 'Reward': '1.50', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 3, 9, 21, 33, 45, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 300, 'QualificationRequirements': [{'QualificationTypeId': '3KPNUZIAIZLB24BL17JZMQ2QTJQ1HV', 'Comparator': 'Exists', 'RequiredToPreview': True, 'ActionsGuarded': 'DiscoverPreviewAndAccept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 1, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '4c3c8b08-5dd4-4219-b53b-bbabc74d76e4', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '4c3c8b08-5dd4-4219-b53b-bbabc74d76e4', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1900', 'date': 'Thu, 07 Mar 2019 02:33:45 GMT'}, 'RetryAttempts': 0}}

# %% [markdown]
# # Download data

# %% [markdown]
# Helper to download data from MTurk

# %%
from bs4 import BeautifulSoup as bs 
import pprint

def pretty_print(obj):
    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(obj)
    pp = None
    
def get_data_from_assignment(a): 
    a_xml = a['Answer']
    soup = bs(a_xml, "html.parser")
    answers = soup.find_all("answer")
    results = {'HITId': a['HITId'], 'AssignmentId': a['AssignmentId'], 'WorkerId': a['WorkerId']}
    for ans in answers: 
        identifier = ans.find('questionidentifier').string
        answer = ans.find('freetext').string
        try: 
            results[identifier] = json.loads(answer)
        except:
            results[identifier] = answer
    return results

# Downloads all the assignments completed for `hits` as a list of dictionaries. 
# If a download_path is given, also saves that data as json 
def get_assignment_content(hits, download_path="", should_print=False): 
    all_responses = []
    for hit in hits: 
        hitid = hit['HITId']
        assignments = get_all_assignments(hitid)
        for a in assignments:
            results = get_data_from_assignment(a)
            all_responses.append(results)
    if should_print: 
        pretty_print(all_responses)
    if download_path: 
        with open(download_path, 'w') as outfile: 
            json.dump(all_responses, outfile)
    return all_responses

_string_clean = lambda s: s.strip().lower()

def test_assignments_for_approval(hits, condition=lambda x: True): 
    to_approve = []
    to_reject = [] 
    for hit in hits: 
        # make sure you keep getting assignments 
        assignments = get_all_assignments(hit["HITId"])
        #print(assignments)
        for a_raw in assignments: 
            a = get_data_from_assignment(a_raw)
            if a_raw['AssignmentStatus'] != 'Approved':
                print("Testing assignment")
                data = condition(a)
                if (data): 
                    print("\tApproved")
                    to_approve.append(a)
                else: 
                    print("\tRejected")
                    to_reject.append(a)
    print("Found %d assignments to approve" % len(to_approve))
    print("Found %d assignments to reject" % len(to_reject))
    return to_approve, to_reject

def approve_all(assignments): 
    for a in assignments: 
        cl.approve_assignment(AssignmentId=a['AssignmentId'])
    print("Succesfully approved %d assignments" % len(assignments))

def get_levels_table(): 
    # WARNING: this assumes you have dumped the most recent version of the db into the folder dump/
    rows = []
    with open(os.path.join("..", "dump", "levels.tsv")) as tsvfile:
        reader = csv.reader(tsvfile, delimiter='\t')
        is_header = True
        headers = {}
        for row in reader:
            if is_header: 
                for i, elt in enumerate(row): 
                    headers[i] = elt
                is_header = False
            else: 
                data = dict([(val, row[key]) for key, val in headers.items()])
                rows.append(data)
    return rows

def is_valid_assignment(a, levels): 
    possible_levels = [l for l in levels if l['assignment_id'] == a['AssignmentId'] and l['score'] is not 'NULL']
    if not possible_levels: 
        return False
    return True

    
    #try: 
    return True
#     except Exception as e: 
#         print("error", e)
#         return False

# %%
# Use this cell to download data
responses = get_assignment_content(hits, download_path='../dump/100responses.json', should_print=True)
pass

# %%
levels = get_levels_table()
condition = lambda a: is_valid_assignment(a, levels)
to_approve, to_reject = test_assignments_for_approval(hits, condition=condition)

# %%
approve_all(to_approve)
